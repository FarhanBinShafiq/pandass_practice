# %%
lives_in = ['Dhaka',
 'Dinajpur',
 'Sylhet',
 'Dhaka',
 'Sylhet',
 'Dhaka',
 'Dhaka',
 'Dhaka',
 'Chittagong',
 'Chittagong',
 'Sylhet',
 'Dhaka',
 'Chittagong',
 'Rajshahi',
 'Chittagong',
 'Dinajpur',
 'Chittagong',
 'Rajshahi',
 'Rajshahi',
 'Chittagong',
 'Rajshahi',
 'Rajshahi',
 'Sylhet',
 'Sylhet',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Chittagong',
 'Sylhet',
 'Sylhet',
 'Chittagong',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Dhaka',
 'Dhaka',
 'Rajshahi',
 'Dhaka',
 'Sylhet',
 'Chittagong',
 'Chittagong',
 'Dhaka',
 'Rajshahi',
 'Sylhet',
 'Sylhet',
 'Rajshahi',
 'Dhaka',
 'Sylhet',
 'Rajshahi',
 'Dhaka',
 'Dhaka',
 'Rajshahi',
 'Dinajpur',
 'Sylhet',
 'Dinajpur',
 'Rajshahi',
 'Chittagong',
 'Dinajpur',
 'Chittagong',
 'Sylhet',
 'Dinajpur',
 'Dinajpur',
 'Rajshahi',
 'Chittagong',
 'Dinajpur',
 'Chittagong',
 'Dhaka',
 'Dinajpur',
 'Rajshahi',
 'Dinajpur',
 'Sylhet',
 'Chittagong',
 'Dhaka',
 'Sylhet',
 'Sylhet',
 'Sylhet',
 'Dinajpur',
 'Sylhet',
 'Dinajpur',
 'Chittagong',
 'Dinajpur',
 'Dhaka',
 'Dhaka',
 'Chittagong',
 'Sylhet',
 'Dhaka',
 'Chittagong',
 'Dhaka',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Dinajpur',
 'Sylhet',
 'Chittagong',
 'Rajshahi',
 'Chittagong',
 'Rajshahi',
 'Chittagong',
 'Rajshahi',
 'Dhaka',
 'Sylhet',
 'Dhaka',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Sylhet',
 'Dhaka',
 'Sylhet',
 'Dinajpur',
 'Dhaka']


livesIn_length=len(lives_in)
print(range(len(lives_in )))

all_names = ['abdullah', 'aminul', 'anwar', 'Arif', 'Asad', 'Ashraful', 'Aziz', 'Babul', 'Badal', 'Bakul', 'Bashir', 'Belayet', 'Bilal', 'Biplob', 'Bishwajit', 'Borhan', 'Chandan', 'Dulal', 'Emon', 'Farhad', 'Firoz', 'Golam', 'Habib', 'Hafiz', 'Hasan', 'Hossain', 'Imran', 'Iqbal', 'Jahangir', 'Jalal', 'Jamal', 'Jashim', 'Kabir', 'Kamal', 'Kawsar', 'Khalil', 'Khokon', 'Khorshed', 'Kuddus', 'Liton', 'Mahbub', 'Mamun', 'Masud', 'Milon', 'Mintu', 'Mirza', 'Mizanur', 'Mofiz', 'Mohammad', 'Mokbul', 'Momin', 'Monir', 'Mostafa', 'Mozammel', 'Mukul', 'Munir', 'Muntasir', 'Musa', 'Mustafizur', 'Nasir', 'Nazrul', 'Nurul', 'Obaidul', 'Oli', 'Osman', 'Parvez', 'Pavel', 'Qayyum', 'Rafiq', 'Rahim', 'Rahman', 'Raihan', 'Raju', 'Rana', 'Rashid', 'Ratan', 'Riaz', 'Rifat', 'Ripon', 'Rokon', 'Rubel', 'Ruhul', 'Russell', 'Saif', 'Salim', 'Sazzad', 'Shahid', 'Shakil', 'Shamim', 'Shamsul', 'Sharif', 'Shawkat', 'Shibli', 'Shohag', 'Shuvo', 'Siddique', 'Sohel', 'Sujon', 'Sumon', 'Sunny', 'Taher', 'Tarek', 'Tariq', 'Tawhid', 'Toufiq', 'Uddin', 'Wahid', 'Yasin', 'Yunus', 'Zahid', 'Zakir', 'Salman']

#print((all_names))
# Out:
# range(0, 112)

# %%
for places in range(livesIn_length) :
    #print(places)

    if lives_in[places]=='Dhaka':
        #print(lives_in[places])
        print(all_names[places] +' lives in ' +lives_in[places])
# Out:
# abdullah lives in Dhaka
# Arif lives in Dhaka
# Ashraful lives in Dhaka
# Aziz lives in Dhaka
# Babul lives in Dhaka
# Belayet lives in Dhaka
# Kawsar lives in Dhaka
# Khalil lives in Dhaka
# Khorshed lives in Dhaka
# Mamun lives in Dhaka
# Mizanur lives in Dhaka
# Mokbul lives in Dhaka
# Momin lives in Dhaka
# Pavel lives in Dhaka
# Raju lives in Dhaka
# Ruhul lives in Dhaka
# Russell lives in Dhaka
# Sazzad lives in Dhaka
# Shakil lives in Dhaka
# Taher lives in Dhaka
# Tariq lives in Dhaka
# Yunus lives in Dhaka
# Salman lives in Dhaka
