# %%
import pandas as pd

#### maximum number of displayed rows and columns to None, effectively displaying all rows and columns when you print a DataFrame.
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df1=pd.read_csv('df1.csv')
df1
# Out:
#      Unnamed: 0        date farmprice atlantaretail chicagoretail  \
# 0            78  2019-04-14     $2.43         $2.48         $1.88
# 1            91  2019-04-07     $2.43         $2.65         $2.73
# 2           105  2019-03-31     $2.34         $2.45         $2.13
# 3           825  2018-05-13     $2.43         $2.48         $2.07
# 4           840  2018-05-06     $2.80         $2.47         $2.56
# 5           854  2018-04-29     $2.52         $2.86         $3.08
# 6           868  2018-04-22     $2.43         $2.56         $2.61
# 7           882  2018-04-15     $1.43         $2.76         $1.98
# 8           896  2018-04-08     $1.52         $3.36         $2.66
# 9           910  2018-04-01     $1.61         $2.86         $2.86
# 10          924  2018-03-25     $2.16         $2.56         $2.56
# 11         1630  2017-05-07     $2.70         $3.75         $2.91
# 12         1643  2017-04-30     $2.87         $3.41         $3.28
# ...

# %%
df1.reset_index()
# Out:
#      index  Unnamed: 0        date farmprice atlantaretail chicagoretail  \
# 0        0          78  2019-04-14     $2.43         $2.48         $1.88
# 1        1          91  2019-04-07     $2.43         $2.65         $2.73
# 2        2         105  2019-03-31     $2.34         $2.45         $2.13
# 3        3         825  2018-05-13     $2.43         $2.48         $2.07
# 4        4         840  2018-05-06     $2.80         $2.47         $2.56
# 5        5         854  2018-04-29     $2.52         $2.86         $3.08
# 6        6         868  2018-04-22     $2.43         $2.56         $2.61
# 7        7         882  2018-04-15     $1.43         $2.76         $1.98
# 8        8         896  2018-04-08     $1.52         $3.36         $2.66
# 9        9         910  2018-04-01     $1.61         $2.86         $2.86
# 10      10         924  2018-03-25     $2.16         $2.56         $2.56
# 11      11        1630  2017-05-07     $2.70         $3.75         $2.91
# ...

# %%
df2=pd.read_csv('df2.csv')
df2
# Out:
#      Unnamed: 0        date farmprice atlantaretail chicagoretail  \
# 0            25  2019-05-12     $1.09         $1.48         $2.11
# 1            50  2019-04-28     $1.27         $1.61         $2.04
# 2            63  2019-04-21     $0.85         $1.64         $2.04
# 3            76  2019-04-14     $0.57         $1.94         $2.24
# 4           103  2019-03-31     $0.73         $1.94         $2.07
# 5           129  2019-03-17     $0.97         $1.94         $2.15
# 6           154  2019-03-03     $1.07         $1.94         $2.15
# 7           167  2019-02-24     $1.17         $1.78         $1.70
# 8           180  2019-02-17     $0.98         $1.78         $2.15
# 9           193  2019-02-10     $1.14         $1.78         $2.49
# 10          205  2019-02-03     $0.75         $1.77         $1.88
# 11          242  2019-01-13     $1.13         $1.61         $2.31
# 12          255  2019-01-06     $1.22         $1.78         $1.79
# ...

# %%
df3=pd.read_csv('df3.csv')
df1
# Out:
#      Unnamed: 0        date farmprice atlantaretail chicagoretail  \
# 0            78  2019-04-14     $2.43         $2.48         $1.88
# 1            91  2019-04-07     $2.43         $2.65         $2.73
# 2           105  2019-03-31     $2.34         $2.45         $2.13
# 3           825  2018-05-13     $2.43         $2.48         $2.07
# 4           840  2018-05-06     $2.80         $2.47         $2.56
# 5           854  2018-04-29     $2.52         $2.86         $3.08
# 6           868  2018-04-22     $2.43         $2.56         $2.61
# 7           882  2018-04-15     $1.43         $2.76         $1.98
# 8           896  2018-04-08     $1.52         $3.36         $2.66
# 9           910  2018-04-01     $1.61         $2.86         $2.86
# 10          924  2018-03-25     $2.16         $2.56         $2.56
# 11         1630  2017-05-07     $2.70         $3.75         $2.91
# 12         1643  2017-04-30     $2.87         $3.41         $3.28
# ...

# %%
df1.merge(df2,left_on='date',right_on='atlantaretail',how='left') ### left one print all table but right only print the matching data.unmatching data will show nan
# Out:
#      Unnamed: 0_x      date_x farmprice_x atlantaretail_x chicagoretail_x  \
# 0              78  2019-04-14       $2.43           $2.48           $1.88
# 1              91  2019-04-07       $2.43           $2.65           $2.73
# 2             105  2019-03-31       $2.34           $2.45           $2.13
# 3             825  2018-05-13       $2.43           $2.48           $2.07
# 4             840  2018-05-06       $2.80           $2.47           $2.56
# 5             854  2018-04-29       $2.52           $2.86           $3.08
# 6             868  2018-04-22       $2.43           $2.56           $2.61
# 7             882  2018-04-15       $1.43           $2.76           $1.98
# 8             896  2018-04-08       $1.52           $3.36           $2.66
# 9             910  2018-04-01       $1.61           $2.86           $2.86
# 10            924  2018-03-25       $2.16           $2.56           $2.56
# 11           1630  2017-05-07       $2.70           $3.75           $2.91
# ...
