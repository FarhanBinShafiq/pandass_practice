# %%
import pandas as pd

# %% [markdown]
# # first
#
# # parse_dates='date column name' date_format='in which format the current column dat eis'
#
# # Second
#
# ##### pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')=======>>>>>>>
# #### to_datetime-----> is convert in the date formate
# # pd.to_datetime(df['column name of the date'],format='%Y-%m-%d %I-%p(which format are in the date column ***not mandatory***)')

# %%
# 1st
df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_format='%Y-%m-%d %I-%p')
df

#2nd 
### same like in[3]-------- in different way
#df['Date']=pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')
#df['Date']
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.head(8)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5 2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6 2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7 2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03  9582732.93

# %%
df.loc[0,'Date'].day_name()
#df['Date'][0].day_name()
# Out:
# 'Friday'

# %%
df['Date']  ## all dates of the column
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df['Date'].dt.day_name() ## day of the date in that columns
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['week day']=df['Date'].dt.day_name() ## here we create new column and add column value as date  day name

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        week day
# ...

# %%
df['Date'].min() #### using min method we can find the earliest time of the column
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max() #### using min method we can find the max time of the column
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max() - df['Date'].min() ### find the time duration
# Out:
# Timedelta('986 days 09:00:00')

# %%
filter=(df['Date']>='2020') ### we can filter our date by this way in this conditions we only show the 2020 dates
df[filter]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#        week day
# 0        Friday
# ...

# %%
filter=(df['week day']=='Friday') ### we can filter our date by this way in this conditions we only show the 2020 dates
df[filter]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23536 2017-07-07 04:00:00  ETHUSD  265.43  266.24  265.43  266.21   449607.51
# 23537 2017-07-07 03:00:00  ETHUSD  264.00  265.45  263.71  265.43   444896.27
# 23538 2017-07-07 02:00:00  ETHUSD  266.00  266.47  263.49  264.00  1271353.18
# 23539 2017-07-07 01:00:00  ETHUSD  265.15  266.00  264.83  266.00   599243.71
# 23540 2017-07-07 00:00:00  ETHUSD  266.01  266.01  264.50  265.15   674625.95
#
#       week day
# 0       Friday
# ...

# %%
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] <= pd.to_datetime('2019-01-31'))
df.loc[filt]     #here we just filter the january months data
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 9788  2019-01-31 00:00:00  ETHUSD  107.61  109.97  107.59  109.69  1279325.87
# 9789  2019-01-30 23:00:00  ETHUSD  107.47  108.24  107.38  107.61   559574.96
# 9790  2019-01-30 22:00:00  ETHUSD  107.35  107.52  107.35  107.47   286652.75
# 9791  2019-01-30 21:00:00  ETHUSD  107.11  107.50  107.10  107.35   506774.22
# 9792  2019-01-30 20:00:00  ETHUSD  107.50  107.81  106.94  107.11   678612.49
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#         week day
# ...

# %%
df.set_index('Date',inplace=True)  ## here we set the date as an index  # inplace=True means we set the index permanantly

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                      week day
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df.loc['2019'] #in this way we can find a selecte dyear info
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     week day
# Date
# 2019-12-31 23:00:00  Tuesday
# 2019-12-31 22:00:00  Tuesday
# ...

# %%
df_sorted = df.sort_index()  #first we have to sort the index than with this sort we can slicing the dates
df_sorted['2019-01-01':'2019-01-31'] # date slicing method 1st is satrting dat and 2 nd is ending date.we can show the 
#result between these date
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-31 19:00:00  ETHUSD  105.11  105.84  105.05  105.71   440680.10
# 2019-01-31 20:00:00  ETHUSD  105.71  106.25  105.49  106.23   460235.89
# 2019-01-31 21:00:00  ETHUSD  106.23  106.23  105.64  105.75   329152.63
# 2019-01-31 22:00:00  ETHUSD  105.75  106.35  105.61  106.24   287372.14
# 2019-01-31 23:00:00  ETHUSD  106.24  106.24  105.53  105.79   154196.70
#
#                      week day
# Date
# 2019-01-01 00:00:00   Tuesday
# ...

# %%
 df_sorted['2019-01-01':'2019-01-31']['Close'].mean() ### mean---------> means avrg of that column between that days
# Out:
# 127.06557795698926

# %%
 df_sorted['2019-01-01':'2019-01-31'].head(10)    # between these only first 10 columns slection
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 05:00:00  ETHUSD  131.96  132.58  131.96  132.48   317851.90
# 2019-01-01 06:00:00  ETHUSD  132.48  133.30  132.48  133.19   436739.05
# 2019-01-01 07:00:00  ETHUSD  133.19  133.99  132.89  133.25   503423.08
# 2019-01-01 08:00:00  ETHUSD  133.25  135.07  133.23  134.60   575950.04
# 2019-01-01 09:00:00  ETHUSD  134.60  134.75  133.29  133.58   345223.15
#
#                     week day
# Date
# 2019-01-01 00:00:00  Tuesday
# 2019-01-01 01:00:00  Tuesday
# 2019-01-01 02:00:00  Tuesday
# 2019-01-01 03:00:00  Tuesday
# ...

# %%
  df_sorted['2019-01-01':'2019-01-31']['High'].max() #max value between these days in High column
# Out:
# 160.61

# %%
  df_sorted['2019-01-01':'2019-01-31'].resample('D').max() #each days highest value #resample("D")___>means we create it as daily basis
# Out:
#             Symbol    Open    High     Low   Close      Volume   week day
# Date
# 2019-01-01  ETHUSD  138.21  140.90  137.68  139.75  3326711.79    Tuesday
# 2019-01-02  ETHUSD  155.21  156.69  153.50  155.21  3127073.00  Wednesday
# 2019-01-03  ETHUSD  153.50  154.44  152.57  153.10  2611463.45   Thursday
# 2019-01-04  ETHUSD  154.15  155.51  153.24  154.15  3376211.66     Friday
# 2019-01-05  ETHUSD  159.43  160.61  158.40  159.43  4907530.32   Saturday
# 2019-01-06  ETHUSD  157.67  159.58  156.62  157.67  4919833.43     Sunday
# 2019-01-07  ETHUSD  156.15  157.15  155.82  156.15  2337492.97     Monday
# 2019-01-08  ETHUSD  152.53  152.90  151.36  152.53  2153105.47    Tuesday
# 2019-01-09  ETHUSD  151.99  152.88  151.85  151.99  2176550.57  Wednesday
# 2019-01-10  ETHUSD  150.64  150.90  150.10  150.64  7407809.95   Thursday
# 2019-01-11  ETHUSD  128.61  128.84  127.43  128.61  1793804.13     Friday
# 2019-01-12  ETHUSD  126.95  127.24  126.21  126.95  1525277.45   Saturday
# ...

# %%
  high=df_sorted['2019-01-01':'2019-01-31'].resample('W').max() #each days highest value #resample("w")___>means we create it as week basis
  high
# Out:
#             Symbol    Open    High     Low   Close      Volume   week day
# Date
# 2019-01-06  ETHUSD  159.43  160.61  158.40  159.43  4919833.43  Wednesday
# 2019-01-13  ETHUSD  156.15  157.15  155.82  156.15  7407809.95  Wednesday
# 2019-01-20  ETHUSD  129.45  131.70  129.00  129.45  6008771.46  Wednesday
# 2019-01-27  ETHUSD  118.69  119.41  118.33  118.69  1937868.14  Wednesday
# 2019-02-03  ETHUSD  111.44  112.10  111.11  111.44  2179638.41  Wednesday

# %%
# %matplotlib inline

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# ...

# %%
high.plot()## we just create the week basis chart
# Out:
# <Axes: xlabel='Date'>

# %%
# Remove non-numeric columns if any
numeric_df = df.select_dtypes(include='number')

# Resample the numeric DataFrame to weekly frequency and calculate the mean
weekly_mean = numeric_df.resample('W').mean()

# Display the resampled DataFrame
print(weekly_mean)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %% [markdown]
# ### agg({})---->we can pass all the columns like dictionary we can mesure all the columns in online what we want see that column

# %%
df.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
