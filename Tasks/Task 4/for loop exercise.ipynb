# %% [markdown]
# Two lists are given-
# 1. `lives_in` which contains names of cities of Bangladesh,
# 2. `all_names` which contains the names of people residing on those two cities. \
# Both lists have equal number of elements shown below:

# %%
lives_in = ['Dhaka',
 'Dinajpur',
 'Sylhet',
 'Dhaka',
 'Sylhet',
 'Dhaka',
 'Dhaka',
 'Dhaka',
 'Chittagong',
 'Chittagong',
 'Sylhet',
 'Dhaka',
 'Chittagong',
 'Rajshahi',
 'Chittagong',
 'Dinajpur',
 'Chittagong',
 'Rajshahi',
 'Rajshahi',
 'Chittagong',
 'Rajshahi',
 'Rajshahi',
 'Sylhet',
 'Sylhet',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Chittagong',
 'Sylhet',
 'Sylhet',
 'Chittagong',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Dhaka',
 'Dhaka',
 'Rajshahi',
 'Dhaka',
 'Sylhet',
 'Chittagong',
 'Chittagong',
 'Dhaka',
 'Rajshahi',
 'Sylhet',
 'Sylhet',
 'Rajshahi',
 'Dhaka',
 'Sylhet',
 'Rajshahi',
 'Dhaka',
 'Dhaka',
 'Rajshahi',
 'Dinajpur',
 'Sylhet',
 'Dinajpur',
 'Rajshahi',
 'Chittagong',
 'Dinajpur',
 'Chittagong',
 'Sylhet',
 'Dinajpur',
 'Dinajpur',
 'Rajshahi',
 'Chittagong',
 'Dinajpur',
 'Chittagong',
 'Dhaka',
 'Dinajpur',
 'Rajshahi',
 'Dinajpur',
 'Sylhet',
 'Chittagong',
 'Dhaka',
 'Sylhet',
 'Sylhet',
 'Sylhet',
 'Dinajpur',
 'Sylhet',
 'Dinajpur',
 'Chittagong',
 'Dinajpur',
 'Dhaka',
 'Dhaka',
 'Chittagong',
 'Sylhet',
 'Dhaka',
 'Chittagong',
 'Dhaka',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Dinajpur',
 'Sylhet',
 'Chittagong',
 'Rajshahi',
 'Chittagong',
 'Rajshahi',
 'Chittagong',
 'Rajshahi',
 'Dhaka',
 'Sylhet',
 'Dhaka',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Rajshahi',
 'Sylhet',
 'Dhaka',
 'Sylhet',
 'Dinajpur',
 'Dhaka']

# %%
all_names = ['abdullah', 'aminul', 'anwar', 'Arif', 'Asad', 'Ashraful', 'Aziz', 'Babul', 'Badal', 'Bakul', 'Bashir', 'Belayet', 'Bilal', 'Biplob', 'Bishwajit', 'Borhan', 'Chandan', 'Dulal', 'Emon', 'Farhad', 'Firoz', 'Golam', 'Habib', 'Hafiz', 'Hasan', 'Hossain', 'Imran', 'Iqbal', 'Jahangir', 'Jalal', 'Jamal', 'Jashim', 'Kabir', 'Kamal', 'Kawsar', 'Khalil', 'Khokon', 'Khorshed', 'Kuddus', 'Liton', 'Mahbub', 'Mamun', 'Masud', 'Milon', 'Mintu', 'Mirza', 'Mizanur', 'Mofiz', 'Mohammad', 'Mokbul', 'Momin', 'Monir', 'Mostafa', 'Mozammel', 'Mukul', 'Munir', 'Muntasir', 'Musa', 'Mustafizur', 'Nasir', 'Nazrul', 'Nurul', 'Obaidul', 'Oli', 'Osman', 'Parvez', 'Pavel', 'Qayyum', 'Rafiq', 'Rahim', 'Rahman', 'Raihan', 'Raju', 'Rana', 'Rashid', 'Ratan', 'Riaz', 'Rifat', 'Ripon', 'Rokon', 'Rubel', 'Ruhul', 'Russell', 'Saif', 'Salim', 'Sazzad', 'Shahid', 'Shakil', 'Shamim', 'Shamsul', 'Sharif', 'Shawkat', 'Shibli', 'Shohag', 'Shuvo', 'Siddique', 'Sohel', 'Sujon', 'Sumon', 'Sunny', 'Taher', 'Tarek', 'Tariq', 'Tawhid', 'Toufiq', 'Uddin', 'Wahid', 'Yasin', 'Yunus', 'Zahid', 'Zakir', 'Salman']

# %% [markdown]
# ### Now, the people in `all_names` lives in the city in `lives_in` in each index respectively as shown in the figure down below:

# %% [markdown]
# ![image.png](attachment:4314549b-9a0d-4e90-a87a-9a5147ac1d4e.png)

# %% [markdown]
# ### Now, only print the names of the people who live in Dhaka.
# ### Generate an output as follows:

# %% [markdown]
# ![image.png](attachment:f6b6932d-48c5-4b19-9ca1-763cd0c4e5fc.png)
